# %%
from selenium import webdriver

# %%
driver = webdriver.Chrome()

# %%
driver.get("https://www.winilogis.com/contents/shipping-schedule?toCountryCode=C0800/South-Korea-to-")

# %%
from selenium.webdriver.common.by import By

# %%
search_button = driver.find_element(By.CLASS_NAME, "react-select__value-container")

# %%
# print(search_button)
search_button.click()
# Out:
# <selenium.webdriver.remote.webelement.WebElement (session="a9bdb2992aa0dafb44b31f55baccbe08", element="f.FA53E0A351505B7B69AFE657FE78E713.d.874E9F0AE2F5A211F941D36B8087B6D6.e.48")>
